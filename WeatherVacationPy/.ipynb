# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
vac_file = pd.read_csv("../output_data/cities.csv")
vac_file1 = pd.DataFrame(vac_file)
vac_file1
# Out:
#      Unnamed: 0           City  Temperature   Wind  Cloud  Humidity  Latitude  \
# 0             0         mehamn        39.20  20.80     75        86     71.04
# 1             1         barrow         8.60   3.36     90        78     71.29
# 2             2          nanma        57.99   8.37      1        73     36.18
# 3             3     el balsamo        87.80   9.17      5        52     15.07
# 4             4          kapaa        71.60   4.70     90        83     22.08
# ..          ...            ...          ...    ...    ...       ...       ...
# 549         549        inirida        77.16   2.93     91        88      3.87
# 550         550        kismayo        83.46  15.99    100        75     -0.36
# 551         551       portland        52.00   5.82     75        81     45.52
# 552         552  cockburn town        78.12  13.20     18        80     21.46
# 553         553         beloha        74.66  21.50      0        70    -25.17
#
#      Longitude Country        Date
# 0        27.85      NO  1587311210
# 1      -156.79      US  1587311141
# 2       118.16      CN  1587311211
# 3       -87.47      HN  1587311211
# 4      -159.32      US  1587311211
# ..         ...     ...         ...
# 549     -67.92      CO  1587311297
# 550      42.55      SO  1587311297
# 551    -122.68      US  1587311231
# 552     -71.14      TC  1587311297
# 553      45.05      MG  1587311297
#
# [554 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
humidity = vac_file1['Humidity'].astype(float)
# Store 'Lat' and 'Lng' into  locations 
locations = vac_file1[["Latitude", "Longitude"]].astype(float)

fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# vac_file1 = pd.DataFrame(vac_file1, columns = ["City", "Temp", "Wind", "Cloud"])
vac_file1 = vac_file1.loc[(vac_file1['Humidity']) >70 & (vac_file1['Humidity'])]
vac_file1 = vac_file1.loc[(vac_file1['Wind']) < 10]
vac_file1 = vac_file1.loc[(vac_file1['Cloud']) == 0]
del vac_file1['Unnamed: 0']
vac_file1 = vac_file1.dropna()
vac_file1
# Out:
#                  City  Temperature  Wind  Cloud  Humidity  Latitude  \
# 26           eyemouth        55.00  1.01      0        62     55.87
# 33              roald        50.00  9.17      0        61     62.58
# 43               hovd        41.27  0.43      0        31     48.01
# 49       marsa matruh        64.40  4.70      0        63     31.35
# 50     port elizabeth        78.80  6.93      0        57    -33.92
# 116            baykit        25.68  2.48      0        91     61.67
# 120         nhulunbuy        82.11  8.88      0        78    -12.23
# 138          ulaangom        36.28  1.72      0        52     49.98
# 142          nanchang        61.23  0.63      0        76     28.68
# 156           laizhou        48.69  9.86      0        86     37.18
# 166            aykhal        21.20  2.24      0        48     66.00
# 186              chuy        71.15  7.92      0        67    -33.70
# 193          zharkent        63.66  4.07      0        22     44.16
# 197         saskylakh        17.65  7.90      0        92     71.92
# 259  diego de almagro        77.88  6.58      0        17    -26.37
# 277              jalu        86.81  5.46      0        13     29.03
# 280           ligayan        85.03  2.01      0        69      4.65
# 342            darhan        29.61  9.46      0        61     49.49
# 362            chadan        43.66  2.24      0        39     51.28
# 372         raudeberg        51.80  5.82      0        43     61.99
# 379       yerbogachen        16.88  2.39      0        91     61.28
# 380       hvide sande        60.01  1.99      0        32     56.00
# 385       thaba-tseka        61.05  9.57      0        22    -29.52
# 390       resistencia        84.00  6.93      0        39    -27.46
# 396      nizhneudinsk        30.99  3.11      0        73     54.91
# 419          vilyuysk         6.66  5.86      0        92     63.76
# 420          tomatlan        82.96  3.15      0        52     19.93
# 435             dalby        51.01  3.36      0        81    -27.18
# 436           thisted        57.00  4.00      0        53     56.96
# 449        valparaiso        77.00  6.93      0        57    -33.04
# 454         byron bay        63.00  6.93      0        93    -28.65
# 466              esna        89.60  5.82      0        27     25.29
# 492           kodinsk        26.42  4.88      0        90     58.69
# 517             pando        79.00  9.17      0        60    -34.72
# 538             rocha        71.83  8.59      0        63    -34.48
# 540    victoria point        66.00  7.47      0        72    -27.58
#
#      Longitude Country        Date
# 26       -2.09      GB  1587311215
# 33        6.13      NO  1587311216
# 43       91.64      MN  1587311217
# 49       27.25      EG  1587311218
# 50       25.57      ZA  1587311218
# 116      96.37      RU  1587311230
# 120     136.77      AU  1587311230
# 138      92.07      MN  1587311234
# 142     115.88      CN  1587311082
# 156     119.93      CN  1587311237
# 166     111.50      RU  1587311239
# 186     -53.46      UY  1587311242
# 193      80.00      KZ  1587311243
# 197     114.08      RU  1587311243
# 259     -70.05      CL  1587311254
# 277      21.55      LY  1587311256
# 280     119.47      PH  1587311257
# 342     105.92      MN  1587311266
# 362      91.58      RU  1587311269
# 372       5.14      NO  1587311270
# 379     108.01      RU  1587311272
# 380       8.13      DK  1587311272
# 385      28.61      LS  1587311273
# 390     -58.98      AR  1587311273
# 396      99.03      RU  1587311274
# 419     121.62      RU  1587311278
# 420    -105.25      MX  1587311278
# 435     151.27      AU  1587311280
# 436       8.69      DK  1587311280
# 449     -71.63      CL  1587311282
# 454     153.62      AU  1587311283
# 466      32.55      EG  1587311284
# 492      99.18      RU  1587311288
# 517     -55.95      UY  1587311292
# 538     -54.33      UY  1587311222
# 540     153.30      AU  1587311232

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = pd.DataFrame(vac_file1, columns = ['City', 'Country', 'Latitude', 'Longitude'])
hotel_df['Hotel Name'] = ''
hotel_df['Latitude'][26]
# Out:
# 55.87

# %%
target_coordinates = f"{hotel_df['Latitude'][26]},{hotel_df['Longitude'][26]}"
target_search = "hotel"
target_radius = 5000
target_type = "hotel"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# hotel_df.iloc[0][0]
# hotel_df.head()

response.json()
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 55.8728855, 'lng': -2.0912916},
#     'viewport': {'northeast': {'lat': 55.87427122989271,
#       'lng': -2.089915970107278},
#      'southwest': {'lat': 55.87157157010727, 'lng': -2.092615629892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '3fb8c12f4d268958748d3b40615858f379e76a2b',
#    'name': 'The Home Arms Bed and Breakfast Guest House',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 637,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114209195060810553855">The home arms</a>'],
#      'photo_reference': 'CmRaAAAA7AlDpStv8vIsIFSET7PtrtBK5UnFNjms4EfQf7PrX5aPL3mx9vbexA9hoBpyd-6uGqs6-IuBNykuVtTOTO6V7FDJ6X7-jjF3OW9QD3DjVe0CtiMH57d178cRN2jL1UfUEhBZii20OZxb6A12OFuedLbrGhSqOZl1epCcsOfRjkwBikKtCwFcSA',
#      'width': 960}],
#    'place_id': 'ChIJS_R3iOI4h0gRPEas-tLxXWg',
#    'plus_code': {'compound_code': 'VWF5+5F Eyemouth, United Kingdom',
#     'global_code': '9C7VVWF5+5F'},
#    'rating': 4.7,
#    'reference': 'ChIJS_R3iOI4h0gRPEas-tLxXWg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 96,
#    'vicinity': 'High St, Eyemouth'},
#   {'geometry': {'location': {'lat': 55.884825, 'lng': -2.15688},
#     'viewport': {'northeast': {'lat': 55.88626152989271,
#       'lng': -2.155442220107278},
#      'southwest': {'lat': 55.88356187010727, 'lng': -2.158141879892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'd3fcf04933199d6d2d2970db0ebed3c7b3994271',
#    'name': 'Priory View',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2269,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105466582942019123002">Priory View</a>'],
#      'photo_reference': 'CmRaAAAA98KuSUBL9DHGJucavY19dW5Yu5_uWgVeRuFSMhc3LSZtNter5JOEpdwYfXi9VFMDO34_L5FSW1pHJol6YfMQwhQQl_3QUJCwWa5WQbKhAv0ZE0v4_ITPgR-vDGtO-j8CEhBrZlxwTsIqGCXSgmM10DC3GhRe2hw1GAcPTaw0u6LbXA-pl6zVXg',
#      'width': 4032}],
#    'place_id': 'ChIJPcqE58I-h0gRWNMRWwvF_0g',
#    'plus_code': {'compound_code': 'VRMV+W6 Coldingham, Eyemouth, United Kingdom',
#     'global_code': '9C7VVRMV+W6'},
#    'rating': 4.7,
#    'reference': 'ChIJPcqE58I-h0gRWNMRWwvF_0g',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 19,
#    'vicinity': 'Eyemouth Road, Coldingham, Eyemouth'},
#   {'geometry': {'location': {'lat': 55.869591, 'lng': -2.0905638},
#     'viewport': {'northeast': {'lat': 55.87097172989272,
#       'lng': -2.089232370107277},
#      'southwest': {'lat': 55.86827207010728, 'lng': -2.091932029892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'a7701cb9ac00fa31fca7bf3e98d5f5416cb0282a',
#    'name': 'The Glenerne Guest House',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 675,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117052469083479779781">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAOb2pF8eeKv4rFL2v1KXLm96tWmF3Gf3GGjPErqxu_Y1gJXKAZjxcqq5qZR7UkBDoIJYkMFQ9IfCJvxLCGNtELQO-onDU4KMXI9GnRdild3L_dH8Cu1sl12TSwmJ_kdM6EhCqRTjURB2w4t8541cSwybhGhTj-GQsCG0xfLirlCSxv7uw8Adf3A',
#      'width': 1200}],
#    'place_id': 'ChIJ621ZBeM4h0gRDd5vI_xEj5s',
#    'plus_code': {'compound_code': 'VW95+RQ Eyemouth, United Kingdom',
#     'global_code': '9C7VVW95+RQ'},
#    'rating': 4.8,
#    'reference': 'ChIJ621ZBeM4h0gRDd5vI_xEj5s',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 17,
#    'vicinity': 'Albert Road, Eyemouth'},
#   {'geometry': {'location': {'lat': 55.8414879, 'lng': -2.0761106},
#     'viewport': {'northeast': {'lat': 55.84279367989272,
#       'lng': -2.074830020107278},
#      'southwest': {'lat': 55.84009402010728, 'lng': -2.077529679892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    'id': 'dada245453c1158267cb1c6673283c643a28d35e',
#    'name': 'The First & Last Pub',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104864315490950054602">George Nesbitt</a>'],
#      'photo_reference': 'CmRaAAAAY2urH_PZq72FbJPaTvzd5NzF9NcWwB2tWcQLcvCOdKmONgF5DgErL6JJKGjU3ilRkrkjUa6B5uGVP19_Eqy0_Xi-KBTFziQInh9MhFnwsVZoWaiqOcj1aiQA4N29p1yaEhCjRpMoNRpnDj-_EM2mBw-cGhT7KoHgFQ0ciE88e3q5qSJo3JHWXg',
#      'width': 5312}],
#    'place_id': 'ChIJja9FnYg4h0gRGvfzKUfUHDc',
#    'plus_code': {'compound_code': 'RWRF+HH Eyemouth, United Kingdom',
#     'global_code': '9C7VRWRF+HH'},
#    'rating': 4.4,
#    'reference': 'ChIJja9FnYg4h0gRGvfzKUfUHDc',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 247,
#    'vicinity': 'Upper Burnmouth, Burnmouth, Eyemouth'},
#   {'geometry': {'location': {'lat': 55.870664, 'lng': -2.1003091},
#     'viewport': {'northeast': {'lat': 55.87172017989272,
#       'lng': -2.099225520107278},
#      'southwest': {'lat': 55.86902052010728, 'lng': -2.101925179892723}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '63f18a02af90e74a038b74ac6babc749f31e672c',
#    'name': 'Eye Sleep Over',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1200,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116973613478716821995">Alex Flockhart</a>'],
#      'photo_reference': 'CmRaAAAAOfuiaa9AWsAhMMM2YvZEbirCNUd4Qy7uQxxdzcWsgCmJlXHnEHcYgHO0vYySBFGnVEurCINxTld5mJy_Prgl51etSAfZwBwW6VgI8oNMArR17ptQYmZvUj_KGf4XEPthEhAer8C8idEO1jJdHNGCgoA9GhSFpVnjdZ5kOmEQmn8_4JHJwwhZpw',
#      'width': 1600}],
#    'place_id': 'ChIJzeNCuuA4h0gRdZE_-uO-wTk',
#    'plus_code': {'compound_code': 'VVCX+7V Eyemouth, United Kingdom',
#     'global_code': '9C7VVVCX+7V'},
#    'rating': 4.6,
#    'reference': 'ChIJzeNCuuA4h0gRdZE_-uO-wTk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 101,
#    'vicinity': 'Toll Bridge Road, Eyemouth'},
#   {'geometry': {'location': {'lat': 55.8727511, 'lng': -2.0913121},
#     'viewport': {'northeast': {'lat': 55.87409882989272,
#       'lng': -2.089955120107278},
#      'southwest': {'lat': 55.87139917010728, 'lng': -2.092654779892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'e316565fab78e9d7975575ca173a4aab8efc2a3a',
#    'name': 'HomeArms Cottage',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 768,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101295860296567778023">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAIjFcGdsedMN25dZUBvkQG_x9_kRvMjKTL-9q93-e0TvmAC3KsX1cJ8uRWIneL9zE6G7qRh5sZdQfxe-wTwbeF0shwLcL0ecPp8QVhtY6UCg0LXx5JLFfEG7w53_0dfJHEhCdWt6IsCxGGUYf4JydaHo_GhRUaddDOC4k4-sXQOF0rg9WwkB_5A',
#      'width': 1024}],
#    'place_id': 'ChIJrddDHCQ5h0gR0ANsdW58ddI',
#    'plus_code': {'compound_code': 'VWF5+4F Eyemouth, United Kingdom',
#     'global_code': '9C7VVWF5+4F'},
#    'rating': 5,
#    'reference': 'ChIJrddDHCQ5h0gR0ANsdW58ddI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Home St, Eyemouth'},
#   {'geometry': {'location': {'lat': 55.8727623, 'lng': -2.0870711},
#     'viewport': {'northeast': {'lat': 55.87404682989272,
#       'lng': -2.085630170107278},
#      'southwest': {'lat': 55.87134717010727, 'lng': -2.088329829892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '25f7a0bd4cf4c4691b301139834f6e0a95aed07e',
#    'name': 'The Old Coach House',
#    'place_id': 'ChIJ5XZ7T_04h0gR1K-DpHwtvNQ',
#    'plus_code': {'compound_code': 'VWF7+45 Eyemouth, United Kingdom',
#     'global_code': '9C7VVWF7+45'},
#    'rating': 4,
#    'reference': 'ChIJ5XZ7T_04h0gR1K-DpHwtvNQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '3Old Quay, Harbour Rd, Eyemouth'},
#   {'geometry': {'location': {'lat': 55.8433199, 'lng': -2.1210157},
#     'viewport': {'northeast': {'lat': 55.84463332989272,
#       'lng': -2.119609870107278},
#      'southwest': {'lat': 55.84193367010728, 'lng': -2.122309529892723}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '394b114b4e95e8f37f53e2b779208b8628a2772e',
#    'name': 'Castle Cottage',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 512,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107268282861379008983">Castle Cottage</a>'],
#      'photo_reference': 'CmRaAAAAByc5eMYcxXyiuCo1nCX0rnWKDflrKPcgktZ6za8eFNkRynF3y1tD_lr4lgS1ovqQjo9E5MBL8EjOXjs5aDu1-CaKOhdIRHJINF_0nn7XFwX4h0lAbTptfzxueG8WWjo7EhAGyPsmzv_ZujHv0xhj9PgeGhQ97U8oKokPU8GhEcJNoQZi5Qn5Vw',
#      'width': 487}],
#    'place_id': 'ChIJVw7u0bM4h0gRIzNcaLM-Zz4',
#    'plus_code': {'compound_code': 'RVVH+8H Eyemouth, United Kingdom',
#     'global_code': '9C7VRVVH+8H'},
#    'rating': 5,
#    'reference': 'ChIJVw7u0bM4h0gRIzNcaLM-Zz4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Old Town, Ayton, Eyemouth'},
#   {'geometry': {'location': {'lat': 55.871799, 'lng': -2.0878007},
#     'viewport': {'northeast': {'lat': 55.87312062989272,
#       'lng': -2.086362970107277},
#      'southwest': {'lat': 55.87042097010728, 'lng': -2.089062629892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '2e3d9ea5df79f2e80a0760f961409672f1f2d32d',
#    'name': "The Ship's Quarters",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 870,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101102828709539148425">A Google User</a>'],
#      'photo_reference': 'CmRZAAAAKAopb4hzOnqN1_pSluIz52Phq3Yj45XLHQgv6LW58-5RcS6iJa_NGIwG2auptlmNzme2YIlhqOrdc4ADhOIZ2i5J6Vhh6dd6klAXccppqutLGIoDiCMy34cbKFYbNUSaEhBrXgu4925x19_yMD-ucw6FGhQ74Ak1fUTMqowaeY3frlNh0GhGiQ',
#      'width': 1410}],
#    'place_id': 'ChIJ10xJfGM5h0gRt5sE4PIXj5o',
#    'plus_code': {'compound_code': 'VWC6+PV Eyemouth, United Kingdom',
#     'global_code': '9C7VVWC6+PV'},
#    'rating': 4.8,
#    'reference': 'ChIJ10xJfGM5h0gRt5sE4PIXj5o',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': 'Harbour Rd, Eyemouth'},
#   {'geometry': {'location': {'lat': 55.8724789, 'lng': -2.0855355},
#     'viewport': {'northeast': {'lat': 55.87382887989272,
#       'lng': -2.083980670107278},
#      'southwest': {'lat': 55.87112922010727, 'lng': -2.086680329892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'eeabaef505981381ea793273855b7c4d929e2c8d',
#    'name': 'Gunsgreen House',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 686,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101750488718138592991">A Google User</a>'],
#      'photo_reference': 'CmRaAAAA4uYVX4QkXN-Slj1eX2AB0SQHKPXZ0-HPZ8-7QtYLIX0Xf-bc5U_2Li4mAcmzMoPIIRDnyZ-CWFju70VdVHB1viy8LL-X5cbQEwLtOo2ZA2SJPvNJdocWveAEzALWqBWsEhCUe0VdjrIx--iqe1iECCspGhS20N6njCWglKbrSLujm8nGkknF6w',
#      'width': 1024}],
#    'place_id': 'ChIJ66VImQI5h0gRPeyF0blk6Cs',
#    'plus_code': {'compound_code': 'VWC7+XQ Eyemouth, United Kingdom',
#     'global_code': '9C7VVWC7+XQ'},
#    'rating': 4.5,
#    'reference': 'ChIJ66VImQI5h0gRPeyF0blk6Cs',
#    'scope': 'GOOGLE',
#    'types': ['tourist_attraction',
#     'lodging',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 94,
#    'vicinity': 'Gunsgreen Quay, Eyemouth'},
#   {'geometry': {'location': {'lat': 55.8904742, 'lng': -2.135511300000001},
#     'viewport': {'northeast': {'lat': 55.89162642989272,
#       'lng': -2.134647020107278},
#      'southwest': {'lat': 55.88892677010728, 'lng': -2.137346679892723}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '06f117611dd0ab6c10368909e83ca06e1249ea29',
#    'name': 'Old Manor',
#    'photos': [{'height': 2976,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100057536706224719125">Pauline Suttie</a>'],
#      'photo_reference': 'CmRaAAAA7cxcgfHtEHLPxj5O7KOJoi2oyvXeNxx9tgApmAv97rQsyOGQWnAPrP2c7I1wrLW_2iTP__EACZkLNDEo8g5IB66EnAHLeCYHQi404c186cf8OMIExmG2Eg7SPO3oySe8EhC89xMdsX14CPHiQxKAWNN-GhSC0Hkv7j0jXN3ISmMa6OBpoF2r6A',
#      'width': 3968}],
#    'place_id': 'ChIJJ3_2dss-h0gRElynzlqSkC8',
#    'plus_code': {'compound_code': 'VVR7+5Q Eyemouth, United Kingdom',
#     'global_code': '9C7VVVR7+5Q'},
#    'rating': 4.1,
#    'reference': 'ChIJJ3_2dss-h0gRElynzlqSkC8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 9,
#    'vicinity': 'Eyemouth'}],
#  'status': 'OK'}

# %%
hotel_df.iloc[0][0]
# Out:
#               City Country  Latitude  Longitude Hotel Name
# 26        eyemouth      GB     55.87      -2.09
# 33           roald      NO     62.58       6.13
# 43            hovd      MN     48.01      91.64
# 49    marsa matruh      EG     31.35      27.25
# 50  port elizabeth      ZA    -33.92      25.57

# %%
hotel_name = []

params = {
    "radius": 5000,
    "types": "hotel",
    "keyword": "hotel",
    "key": g_key
}

# taken from Airpost_Ratings Example done in class
for index, row in hotel_df.iterrows():
    # get lat, lng from df
    latitude = row["Latitude"]
    longitude = row["Longitude"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{latitude},{longitude}"

    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    
    # convert to json
    name_address = name_address.json()
    
    
    # print(json.dumps(name_address, indent=4, sort_keys=True))
    try:
#         hotel_df.iloc[index, 4] = name_address['results'][0]['name']
        hotel_name.append(name_address['results'][0]['name'])
    except IndexError:
        hotel_name.append(np.nan)

# %%
hotel_df['Hotel Name'] = hotel_name
hotel_df.head()
# Out:
#               City Country  Latitude  Longitude  \
# 26        eyemouth      GB     55.87      -2.09
# 33           roald      NO     62.58       6.13
# 43            hovd      MN     48.01      91.64
# 49    marsa matruh      EG     31.35      27.25
# 50  port elizabeth      ZA    -33.92      25.57
#
#                                      Hotel Name
# 26  The Home Arms Bed and Breakfast Guest House
# 33                   Vestavind Hytter og Rom AS
# 43                                 Steppe hotel
# 49                                    Beau Site
# 50                          Millbury Guesthouse

# %%
hotel_df.dropna()
hotel_df.to_csv('../output_data/hotel.csv')

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
# Add marker layer ontop of heat map
hotel_something = hotel_df['Hotel Name'].tolist()
hotel_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=1,
    info_box_content=[f"Bank amount: {hotel}" for hotel in hotel_something]
)

fig.add_layer(hotel_layer)
# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
